# %%
#Importing libraries
import pandas as pd
from tabulate import tabulate
# %pip install matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\denis\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
EconomicDF = pd.read_csv("C:/Users/denis/OneDrive/VSCode/Git/culminating-project-group-2/WEEK 4/EconomicData106.csv")
EnviornmentDF = pd.read_csv("C:/Users/denis/OneDrive/VSCode/Git/culminating-project-group-2/Database/DataSources/World Development Indicators (WDI)/Envirnmental_Indicators.csv")

# %%
#Display the first 10 rows of the EconomicDF DataFrame
EconomicDF.head(10)
# Out:
#   Country Name Country Code    Time Time Code  \
# 0      Albania          ALB  2021.0    YR2021
# 1      Albania          ALB  2022.0    YR2022
# 2      Albania          ALB  2023.0    YR2023
# 3    Argentina          ARG  2021.0    YR2021
# 4    Argentina          ARG  2022.0    YR2022
# 5    Argentina          ARG  2023.0    YR2023
# 6      Armenia          ARM  2021.0    YR2021
# 7      Armenia          ARM  2022.0    YR2022
# 8      Armenia          ARM  2023.0    YR2023
# 9    Australia          AUS  2021.0    YR2021
#
#   Adjusted Net National Income(Yrly % Growth)  \
# 0                                 11.05709518
# 1                                          ..
# 2                                          ..
# 3                                 12.48955577
# 4                                          ..
# 5                                          ..
# 6                                  2.40277797
# 7                                          ..
# ...

# %%
#dropping time code and conutry code
EconomicDF = EconomicDF.drop(columns=['Country Code', 'Time Code'])
EconomicDF = EconomicDF.rename(columns={'Country Name': 'Country', 'Time': 'Year'})

# %%
#Display info about the EnviornmentDF DataFrame
EconomicDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 66 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Country                                                                       318 non-null    object
#  1   Year                                                                          318 non-null    float64
#  2   Adjusted Net National Income(Yrly % Growth)                                   318 non-null    object
#  3   Adjusted Net Natiobnal Income (Constant)                                      318 non-null    object
#  4   Adjusted Net National Income (Current)                                        318 non-null    object
#  5   Current Account Balance (% GDP)                                               318 non-null    object
# ...

# %%
#list variable names in the EconomicDF DataFrame
EconomicDF.columns.tolist()
# Out:
# ['Country',
#  'Year',
#  'Adjusted Net National Income(Yrly % Growth)',
#  'Adjusted Net Natiobnal Income (Constant)',
#  'Adjusted Net National Income (Current)',
#  'Current Account Balance (% GDP)',
#  'Current Account Balance (BoP Current $)',
#  'Exports Goods and Services (% GDP)',
#  'Exports Goods and Services (Yrly % growth)',
#  'Exports of Goods and Services (Current $)',
#  'External Balance on Goods and Services (Constant LCU)',
#  'Foreign Direct Investment, Net (Current $)',
#  'Foreign Direct Investment, Net Inflows (% of GDP)',
#  'Foreign Direct Investment, Net Inflows (Current $)',
#  'Foreign Direct Investment, Net Outflows (% of GDP)',
#  'Foreign Direct Investment, Net Outflows (Current $)',
#  'GDP (Constant 2015 $)',
#  'GDP (Constant LCU)',
#  'GDP (Current LCU)',
#  'GDP (Current $)',
#  'GDP Growth (Yrly %)',
#  'GDP per capita (Constant 2015 $)',
#  'GDP per capita (Constant LCU)',
#  'GDP per capita (Current LCU)',
#  'GDP per Capita (Current $)',
# ...

# %%
# Create a new DataFrame with the columns of interest that exist in EconomicDF
# Ensure the column names exist in the DataFrame
columnsInterest = ['Country', 'Year', 'GDP (Current $)', 'GDP Growth (Yrly %)', 'GDP per Capita (Current $)', 'Adjusted Net National Income(Yrly % Growth)',
 'Adjusted Net Natiobnal Income (Constant)', 'Adjusted Net National Income (Current)', 'Service Exports (Current $)', 'Service Imports (Current $)']
EconomicDF = EconomicDF[columnsInterest]

# %%
#number of columns ib EconomicDF DataFrame
EconomicDF.shape # Display the number of columns in the EconomicDF DataFrame
# Out:
# (318, 10)

# %%
#Display information about the EconomicDF DataFrame
EnviornmentDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803 entries, 0 to 802
# Data columns (total 11 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Country Name                                                                                       800 non-null    object
#  1   Country Code                                                                                       798 non-null    object
#  2   Time                                                                                               798 non-null    float64
#  3   Time Code                                                                                          798 non-null    object
# ...

# %%
#drop time code and conutry code
EnviornmentDF = EnviornmentDF.drop(columns=['Country Code', 'Time Code'])
EnviornmentDF = EnviornmentDF.rename(columns={'Country Name': 'Country', 'Time': 'Year'})

# %%
# Handle NaN values in the Year column before converting to float
EnviornmentDF['Year'] = EnviornmentDF['Year'].fillna(0).astype(float).astype(int)

# %%
#removing countries that are not part of prechosen 106 countries
specifiedCountries = ['Albania', 'Argentina', 'Armenia', 'Australia', 'Austria', 
                      'Bangladesh', 'Barbados', 'Belgium', 'Bolivia', 'Bosnia and Herzegovina', 
                      'Botswana', 'Brazil', 'Bulgaria', 'Burkina Faso', 'Cambodia', 'Canada', 'Chile', 'China', 'Colombia', 
                      'Congo, Dem. Rep.', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cyprus', 'Czechia', 'Denmark', 'Dominican Republic', 
                      'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia', 'Germany', 'Greece', 'Guatemala', 'Honduras', 
                      'Hungary', 'Iceland', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Kenya', 'Korea, Rep.', 'Kosovo',
                      'Kyrgyz Republic', 'Latvia', 'Lebanon', 'Lesotho', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
                      'Malta', 'Mauritius', 'Mexico', 'Moldova', 'Mongolia', 'Morocco', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Nigeria', 
                      'North Macedonia', 'Norway', 'Pakistan', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Romania',
                      'Russian Federation', 'Rwanda', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Slovak Republic', 'Slovenia', 
                      'Solomon Islands', 'South Africa', 'Spain', 'Sri Lanka', 'St. Lucia', 'Suriname', 'Sweden', 'Switzerland', 'Tajikistan', 
                      'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga', 'Turkiye', 'Uganda', 'United Kingdom', 'United States', 'Uruguay']

#Filter the data to include only the specified countries
EnviornmentDF = EnviornmentDF[EnviornmentDF['Country'].isin(specifiedCountries)]

# %%
#Displaying the count of unique items in the 'Country Name' column
print(f'Unique Country Name column: {EnviornmentDF["Country"].nunique()}')
# Out:
# Unique Country Name column: 106

# %%
#identifying data types and missing values in one table
#Get the data types
dtypes = EnviornmentDF.dtypes

# Get the number of missing values
missingValues = EnviornmentDF.isna().sum()

#Creating a new DataFrame for combined information
info = pd.DataFrame({'Column': dtypes.index,'DataType': dtypes.values,'MissingValues': missingValues.values})

#Converting DataFrame to table format with right alignment
table = tabulate(info, headers='keys', tablefmt='pretty', showindex=False, colalign=("right", "right", "right"))
print(table)
# Out:
# +---------------------------------------------------------------------------------------------------+----------+---------------+
# |                                                                                            Column | DataType | MissingValues |
# +---------------------------------------------------------------------------------------------------+----------+---------------+
# |                                                                                           Country |   object |             0 |
# |                                                                                              Year |    int64 |             0 |
# |  Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) [EN.GHG.CO2.ZG.AR5] |   object |             0 |
# |          Carbon dioxide (CO2) emissions (total) excluding LULUCF (Mt CO2e) [EN.GHG.CO2.MT.CE.AR5] |   object |             0 |
# ...

# %%
#convert columns except for 'Country' and 'Year' to numeric
EnviornmentDF.iloc[:, 2:] = EnviornmentDF.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
# Display the first 10 rows of the EnviornmentDF DataFrame after conversion
EnviornmentDF.head(10)
# Out:
#       Country  Year  \
# 3     Albania  2021
# 4     Albania  2022
# 5     Albania  2023
# 21  Argentina  2021
# 22  Argentina  2022
# 23  Argentina  2023
# 24    Armenia  2021
# 25    Armenia  2022
# 26    Armenia  2023
# 30  Australia  2021
#
#    Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) [EN.GHG.CO2.ZG.AR5]  \
# 3                                          -24.164033
# 4                                          -30.639579
# 5                                           -30.89842
# 21                                          90.304988
# 22                                          93.119308
# 23                                          83.434277
# 24                                         -63.863504
# 25                                         -64.921728
# 26                                         -62.824529
# 30                                          38.516443
#
# ...

# %%
#filling missing values with 0
EnviornmentDF = EnviornmentDF.fillna(0)

#Display the first 10 rows of the EnviornmentDF
EnviornmentDF.head(10)
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_30536\2414126219.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   EnviornmentDF = EnviornmentDF.fillna(0)
#       Country  Year  \
# 3     Albania  2021
# 4     Albania  2022
# 5     Albania  2023
# 21  Argentina  2021
# 22  Argentina  2022
# 23  Argentina  2023
# 24    Armenia  2021
# 25    Armenia  2022
# 26    Armenia  2023
# 30  Australia  2021
#
#     Carbon dioxide (CO2) emissions (total) excluding LULUCF (% change from 1990) [EN.GHG.CO2.ZG.AR5]  \
# 3                                          -24.164033
# 4                                          -30.639579
# 5                                          -30.898420
# 21                                          90.304988
# ...
