# %%
# Display columns with more than a certain percentage of missing values (e.g., 50%)
high_missing = missing_percentage_df[missing_percentage_df['Missing Percentage'] > 50]

# Print the result
print(high_missing)
# Out:
#                                           Column Name  Missing Percentage
# 3   Gross PSD, Budgetary Central Gov., All maturit...           70.440252
# 4   Gross PSD, Budgetary Central Gov., All maturit...           62.893082
# 5   Gross PSD, Budgetary Central Gov., All maturit...           62.893082
# 6   Gross PSD, Budgetary Central Gov., All maturit...           68.553459
# 7   Gross PSD, Budgetary Central Gov., All maturit...           61.006289
# 8   Gross PSD, Budgetary Central Gov., All maturit...           61.006289
# 9   Gross PSD, Budgetary Central Gov., All maturit...           67.610063
# 10  Gross PSD, Budgetary Central Gov., All maturit...           60.062893
# 11  Gross PSD, Budgetary Central Gov., All maturit...           60.062893
# 12  Gross PSD, Budgetary Central Gov., All maturit...           90.566038
# 13  Gross PSD, Budgetary Central Gov., Long-term, ...           67.610063
# 14  Gross PSD, Budgetary Central Gov., Long-term, ...           60.062893
# ...

# %%
df.shape
# Out:
# (318, 65)

# %%
import pandas as pd
df = pd.read_csv('/content/Public_Debt_Indicators.csv')
missing_percentage = df.isnull().sum() * 100 / len(df)
print(missing_percentage)
# Out:
# Country Name                                                                                                                   0.0
# Country Code                                                                                                                   0.0
# Year                                                                                                                           0.0
# Gross PSD, Budgetary Central Gov., All maturities, All instruments, External creditors, Nominal Value, % of GDP                0.0
# Gross PSD, Budgetary Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency       0.0
# Gross PSD, Budgetary Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$                     0.0
# Gross PSD, Budgetary Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP                  0.0
# ...

# %%
import pandas as pd

# Replace "........" with NaN
df.replace("........", pd.NA, inplace=True)

# Calculate the percentage of missing values for each column
missing_percentage = df.isnull().mean() * 100

# Create a DataFrame with the results
missing_percentage_df = pd.DataFrame({
    'Column Name': missing_percentage.index,
    'Missing Percentage': missing_percentage.values
})

# Sort the DataFrame by Missing Percentage
sorted_missing_percentage_df = missing_percentage_df.sort_values(by='Missing Percentage', ascending=True)

# Display all columns
pd.set_option('display.max_rows', None)  # Set to None to display all rows
print(sorted_missing_percentage_df)
# Out:
#                                           Column Name  Missing Percentage
# 0                                        Country Name            0.000000
# 1                                        Country Code            0.000000
# 2                                                Year            0.000000
# 27  Gross PSD, Central Gov., All maturities, All i...           17.295597
# 26  Gross PSD, Central Gov., All maturities, All i...           17.295597
# 25  Gross PSD, Central Gov., All maturities, All i...           28.930818
# 20  Gross PSD, Central Gov., All maturities, All i...           34.276730
# 21  Gross PSD, Central Gov., All maturities, All i...           34.276730
# 24  Gross PSD, Central Gov., All maturities, All i...           36.163522
# 23  Gross PSD, Central Gov., All maturities, All i...           36.163522
# 47  Gross PSD, General Gov., All maturities, All i...           38.679245
# 46  Gross PSD, General Gov., All maturities, All i...           38.679245
# ...

# %%
import pandas as pd

# Replace "........" with NaN
df.replace("........", pd.NA, inplace=True)

# Calculate the percentage of missing values for each column
missing_percentage = df.isnull().mean() * 100

# Identify columns with more than 60% missing values
columns_to_drop = missing_percentage[missing_percentage > 60].index

# Drop the identified columns from the DataFrame
df_dropped = df.drop(columns=columns_to_drop)

# Optionally, print the remaining columns to verify
print("Remaining columns after dropping:")
print(df_dropped.columns)
# Out:
# Remaining columns after dropping:
# Index(['Country Name', 'Country Code', 'Year',
#        'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, % of GDP',
#        'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency',
#        'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$',
#        'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP',
#        'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency',
#        'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, US$',
#        'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, % of GDP',
#        'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, National Currency',
# ...

# %%
import pandas as pd

# Assuming you have already created your DataFrame `df`
# Replace "........" with NaN
df.replace("........", pd.NA, inplace=True)

# Calculate the percentage of missing values for each column
missing_percentage = df.isnull().mean() * 100

# Identify columns with more than 60% missing values
columns_to_drop = missing_percentage[missing_percentage > 60].index

# Drop the identified columns from the DataFrame
df_dropped = df.drop(columns=columns_to_drop)

# Save the cleaned DataFrame as a CSV file
df_dropped.to_csv('cleaned_data.csv', index=False)

print("Cleaned DataFrame saved as 'cleaned_data.csv'")
# Out:
# Cleaned DataFrame saved as 'cleaned_data.csv'

# %%
df_cleaned.shape
# Out:
# (318, 20)

# %%
import pandas as pd

# Assuming df is your original DataFrame with missing values
df_filled = df_dropped.fillna(method='ffill')
# Out:
# <ipython-input-39-8f8067d4f123>:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filled = df_dropped.fillna(method='ffill')

# %%
df_filled = df_dropped.fillna(method='ffill').fillna(method='bfill')
# Out:
# <ipython-input-42-bd32492fb93e>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filled = df_dropped.fillna(method='ffill').fillna(method='bfill')

# %%
print(df_dropped.isnull().sum())
columns_to_drop = df_dropped.columns[df_dropped.isnull().sum() == len(df_dropped)]
df_dropped = df_dropped.drop(columns=columns_to_drop)
# Out:
# Country Name                                                                                                        0
# Country Code                                                                                                        0
# Year                                                                                                                0
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, % of GDP             318
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency      9
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$                    9
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP               120
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency       18
# ...

# %%
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Assuming df_dropped is your DataFrame

# Step 1: Identify relevant columns with non-missing values
number_columns = df_dropped.select_dtypes(include=['number']).columns
relevant_columns = number_columns[df_dropped[number_columns].isnull().sum() < len(df_dropped)]

# Step 2: Apply Iterative Imputer only to relevant columns
iterative_imputer = IterativeImputer()
df_filled = iterative_imputer.fit_transform(df_dropped[relevant_columns])

# Step 3: Create a DataFrame from filled values
df_filled = pd.DataFrame(df_filled, columns=relevant_columns)

# Step 4: Combine filled DataFrame with original DataFrame (excluding filled columns)
df_combined = pd.concat([df_dropped.drop(columns=relevant_columns), df_filled], axis=1)

# Step 5: Check for remaining missing values
print(df_combined.isnull().sum())
# Out:
# Country Name                                                                                                      0
# Country Code                                                                                                      0
# Year                                                                                                              0
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency    0
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$                  0
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP               0
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency      0
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, US$                    0
# ...

# %%
# Save the DataFrame as a CSV file
df_combined.to_csv('cleaned_data.csv', index=False)

# %%
print(df_combined.describe())  # Get a summary of the filled DataFrame
# Out:
#               Year  \
# count   318.000000
# mean   2022.000000
# std       0.817783
# min    2021.000000
# 25%    2021.000000
# 50%    2022.000000
# 75%    2023.000000
# max    2023.000000
#
#        Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency  \
# count                                       3.180000e+02
# mean                                        3.486051e+62
# std                                         3.044567e+63
# min                                         4.486070e+09
# 25%                                         1.710570e+43
# 50%                                         2.500510e+47
# 75%                                         3.682215e+51
# max                                         2.727835e+64
#
#        Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$  \
# count                                       3.180000e+02
# ...

# %%
# Specify the filename you want to save the DataFrame as
filename = 'imputed_dataset.csv'

# Save the DataFrame to a CSV file
df_dropped.to_csv(filename, index=False)

print(f"The dataset has been saved as '{filename}'.")
# Out:
# The dataset has been saved as 'imputed_dataset.csv'.

# %%
# Check the data types of all columns
print("Data types of columns:")
print(df_dropped.dtypes)
# Out:
# Data types of columns:
# Country Name                                                                                                      object
# Country Code                                                                                                      object
# Year                                                                                                               int64
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, % of GDP             object
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency    object
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$                  object
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP               object
# ...

# %%
# Identify columns that should be numeric
numeric_columns = [
    'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, % of GDP',
    'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency',
    'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$',
    'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP',
    'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency',
    'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, US$',
    'Gross PSD, General Gov., All maturities, All instruments, External creditors, Nominal Value, % of GDP',
    'Gross PSD, General Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency',
    'Gross PSD, General Gov., All maturities, All instruments, External creditors, Nominal Value, US$',
    'Gross PSD, General Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency',
    'Gross PSD, General Gov., All maturities, All instruments, Foreign currency, Nominal Value, US$',
    'Gross PSD, General Gov., All maturities, All instruments, Nominal Value, % of GDP',
    'Gross PSD, General Gov., All maturities, All instruments, Nominal Value, National Currency',
    'Gross PSD, General Gov., All maturities, All instruments, Nominal Value, US$',
    'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, % of GDP',
    'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, National Currency',
    'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, US$'
]

# Convert these columns to numeric, coercing errors
df_dropped[numeric_columns] = df_dropped[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
# Check the data types of all columns again
print("Data types of columns after conversion:")
print(df_dropped.dtypes)
# Out:
# Data types of columns after conversion:
# Country Name                                                                                                       object
# Country Code                                                                                                       object
# Year                                                                                                                int64
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, % of GDP             float64
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency    float64
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$                  float64
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP               float64
# ...

# %%
import pandas as pd

df_dropped = pd.read_csv('/content/imputed_dataset.csv')

# %%
print(df_dropped.dtypes)
# Out:
# Country Name                                                                                                       object
# Country Code                                                                                                       object
# Year                                                                                                                int64
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, % of GDP             float64
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency    float64
# Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$                  float64
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP               float64
# Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency      float64
# ...

# %%
numeric_df = df_combined.select_dtypes(include=['number'])

# %%
correlationmatrix = numeric_df.corr()

# %%
# Set the threshold for high correlation
threshold = 0.90  # Adjust as needed

# Find highly correlated pairs of columns
highly_correlated_pairs = []

# Iterate over the correlation matrix
for i in range(len(correlationmatrix.columns)):
    for j in range(i+1, len(correlationmatrix.columns)):
        if abs(correlationmatrix.iloc[i, j]) > threshold:
            # If correlation coefficient is above threshold, add the pair to the list
            highly_correlated_pairs.append((correlationmatrix.columns[i], correlationmatrix.columns[j]))

highly_correlated_pairs
# Out:
# [('Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency',
#   'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$'),
#  ('Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency',
#   'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP'),
#  ('Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency',
#   'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency'),
#  ('Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency',
#   'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, US$'),
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
sns.heatmap(correlationmatrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example for the first pair
col1, col2 = highly_correlated_pairs[0]
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_combined, x=col1, y=col2)
plt.title(f'Scatter Plot of {col1} vs {col2}')
plt.xlabel(col1)
plt.ylabel(col2)
plt.show()

# %%
print(df_combined.columns.tolist())
# Out:
# ['Country Name', 'Country Code', 'Year', 'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency', 'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$', 'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP', 'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency', 'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, US$', 'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, % of GDP', 'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, National Currency', 'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, US$', 'Gross PSD, General Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency', 'Gross PSD, General Gov., All maturities, All instruments
# ...

# %%
numeric_columns = df_combined.select_dtypes(include=['number']).columns.tolist()
print(numeric_columns)
# Out:
# ['Year', 'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency', 'Gross PSD, Central Gov., All maturities, All instruments, External creditors, Nominal Value, US$', 'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, % of GDP', 'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, National Currency', 'Gross PSD, Central Gov., All maturities, All instruments, Foreign currency, Nominal Value, US$', 'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, % of GDP', 'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, National Currency', 'Gross PSD, Central Gov., All maturities, All instruments, Nominal Value, US$', 'Gross PSD, General Gov., All maturities, All instruments, External creditors, Nominal Value, National Currency', 'Gross PSD, General Gov., All maturities, All instruments, External creditors, Nominal Va
# ...

# %%
# Filter numeric_columns to include only those present in df_combined
numeric_columns = [col for col in numeric_columns if col in df_combined.columns]

# Now create the histogram
df_combined[numeric_columns].hist(figsize=(15, 10), bins=30)
plt.tight_layout()
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Select only numeric columns for PCA
numeric_columns = df_combined.select_dtypes(include=['number']).columns

# Standardize the data
scaler = StandardScaler()
standardized_data = scaler.fit_transform(df_combined[numeric_columns])

# %%
# Initialize PCA to keep 3 components
pca = PCA(n_components=3)
principal_components = pca.fit_transform(standardized_data)

# %%
# Create a DataFrame with custom names for the principal components
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2', 'PC3'])

# %%
result_df = pd.concat([df_combined.reset_index(drop=True), pca_df], axis=1)

# %%
# Get the statistical summary of the principal components
summary = pca_df.describe()
print(summary)
# Out:
#                 PC1           PC2           PC3
# count  3.180000e+02  3.180000e+02  3.180000e+02
# mean   8.937644e-17  5.027425e-17  1.731669e-16
# std    3.469764e+00  1.007369e+00  9.950424e-01
# min   -4.408027e-01 -1.067186e+00 -7.333932e+00
# 25%   -4.100525e-01 -9.149827e-01 -8.137343e-01
# 50%   -3.968997e-01 -6.920592e-02  7.197935e-02
# 75%   -3.837469e-01  7.765708e-01  9.576930e-01
# max    3.070044e+01  9.460371e+00  9.576930e-01

# %%
explained_variance = pca.explained_variance_ratio_
print(f'Explained variance by each component: {explained_variance}')
# Out:
# Explained variance by each component: [0.8572431 0.0722572 0.0704997]

# %%
import seaborn as sns

# Create a scatter plot of PC1 vs. PC2
plt.figure(figsize=(6, 6))
sns.scatterplot(x='PC1', y='PC2', data=pca_df)

# Add titles and labels
plt.title('PCA: Scatter Plot of PC1 vs PC2')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.grid(True)
plt.axhline(0, color='gray', lw=0.5, ls='--')
plt.axvline(0, color='gray', lw=0.5, ls='--')

# Show the plot
plt.show()
